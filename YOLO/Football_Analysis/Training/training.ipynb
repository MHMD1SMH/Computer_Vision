# %%
from roboflow import Roboflow
rf = Roboflow(api_key="8pKDi256TYNSI88nYikr")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolo26")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolo26:: 100%|██████████| 147802/147802 [01:11<00:00, 2066.09it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolo26:: 100%|██████████| 1338/1338 [00:00<00:00, 8371.45it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolo26m.pt")
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26m.pt to 'yolo26m.pt': 100% ━━━━━━━━━━━━ 42.2MB 2.4MB/s 17.7s7.7s<0.1s.9s

# %%
results = model.train(
    data=f"{dataset.location}/data.yaml",
    epochs=100,
    imgsz=640,
    batch=16,
    project="runs/detect",
    name="football_players",
    patience=10,
    device=0
)
# Out:
# New https://pypi.org/project/ultralytics/8.4.161 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.120 🚀 Python-3.14.4 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5806MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=False, cfg=None, channels_last=False, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, cls_remap=True, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/mohamed-sameh/Computer_Vision/YOLO/Football_Analysis/Training/football-players-detection-1/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dgrad=0.5, dis=6.0, distill_model=None, dlam=1.0, dlog=1.0, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=/home/mohamed-sameh/Computer_Vision/runs/detect/train-2/weights/best.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=football_players-2, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=10, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/detect, quantize=None, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=tracktrack.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1856  ultralytics.nn.modules.conv.Conv             [3, 64, 3, 2]
#   1                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   2                  -1  1    111872  ultralytics.nn.modules.block.C3k2            [128, 256, 1, True, 0.25]
#   3                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#   4                  -1  1    444928  ultralytics.nn.modules.block.C3k2            [256, 512, 1, True, 0.25]
#   5                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   6                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   7                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#   8                  -1  1   1380352  ultralytics.nn.modules.block.C3k2            [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5, 3, True]
#  10                  -1  1    990976  ultralytics.nn.modules.block.C2PSA           [512, 512, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1   1642496  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1    542720  ultralytics.nn.modules.block.C3k2            [1024, 256, 1, True]
#  17                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1   1511424  ultralytics.nn.modules.block.C3k2            [768, 512, 1, True]
#  20                  -1  1   2360320  ultralytics.nn.modules.conv.Conv             [512, 512, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1   1974784  ultralytics.nn.modules.block.C3k2            [1024, 512, 1, True, 0.5, True]
#  23        [16, 19, 22]  1   2804784  ultralytics.nn.modules.head.Detect           [4, 1, True, [256, 512, 512]]
# YOLO26m summary: 280 layers, 21,779,056 parameters, 21,779,056 gradients, 75.0 GFLOPs
#
# Transferred 768/768 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3877.2±2129.3 MB/s, size: 228.7 KB)
# train: Scanning /home/mohamed-sameh/Computer_Vision/YOLO/Football_Analysis/Training/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 171.1Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 3304.9±160.0 MB/s, size: 208.1 KB)
# val: Scanning /home/mohamed-sameh/Computer_Vision/YOLO/Football_Analysis/Training/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 9.4Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# Plotting labels to /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2
# Starting training for 100 epochs...
# WARNING ⚠️ CUDA out of memory with batch=16. Reducing to batch=8 and retrying (1/3).
# [W924 19:54:36.953854511 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 27262976 bytes (free: 27656192, total: 6088359936).
# [W924 19:54:36.953972105 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 27262976 bytes (free: 27656192, total: 6088359936).
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1264.4±551.0 MB/s, size: 227.4 KB)
# train: Scanning /home/mohamed-sameh/Computer_Vision/YOLO/Football_Analysis/Training/football-players-detection-1/train/labels.cache... 612 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 612/612 233.4Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 277.3±167.3 MB/s, size: 237.9 KB)
# val: Scanning /home/mohamed-sameh/Computer_Vision/YOLO/Football_Analysis/Training/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 38/38 7.6Mit/s 0.0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 124 weight(decay=0.0), 136 weight(decay=0.0005), 136 bias(decay=0.0)
# : 0% ──────────── 0/39  8.6s
# [W924 19:54:45.039473651 CUDACachingAllocator.cpp:3933] memory allocation failed with OOM on device 0 while trying to allocate 2097152 bytes (free: 2490368, total: 6088359936).
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       1/100      5.18G      1.074     0.3627  0.0008272        139        640: 100% ━━━━━━━━━━━━ 77/77 3.7it/s 20.8s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.8it/s 0.3s0.8s
#                    all         38        905      0.835      0.733      0.807      0.523
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       2/100      5.34G      1.087     0.3803  0.0008653         87        640: 100% ━━━━━━━━━━━━ 77/77 3.8it/s 20.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.2it/s 0.3s0.8s
#                    all         38        905      0.907      0.794      0.831      0.548
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       3/100       5.3G      1.173     0.4048  0.0009226        177        640: 100% ━━━━━━━━━━━━ 77/77 3.8it/s 20.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.4it/s 0.3s0.7s
#                    all         38        905      0.889      0.788      0.839       0.53
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       4/100      5.38G      1.165     0.3951  0.0009352        193        640: 100% ━━━━━━━━━━━━ 77/77 3.8it/s 20.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.1it/s 0.3s0.7s
#                    all         38        905      0.951      0.773      0.832      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       5/100      5.39G      1.172     0.3971  0.0009088        161        640: 100% ━━━━━━━━━━━━ 77/77 3.7it/s 21.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.0it/s 0.3s0.8s
#                    all         38        905      0.914       0.76       0.83      0.542
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       6/100      5.39G      1.146     0.3801   0.000916         73        640: 100% ━━━━━━━━━━━━ 77/77 3.7it/s 21.0s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.2it/s 0.3s0.7s
#                    all         38        905      0.931      0.791      0.846      0.566
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       7/100      5.32G      1.114     0.3705  0.0008884        122        640: 100% ━━━━━━━━━━━━ 77/77 3.7it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.878      0.783      0.828      0.563
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       8/100      5.39G      1.123     0.3693  0.0008542        102        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.1s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.852      0.828      0.817      0.556
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#       9/100      5.39G      1.092      0.356  0.0008801        138        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.2it/s 0.3s0.7s
#                    all         38        905      0.846      0.822      0.843      0.572
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      10/100      5.39G      1.077     0.3441  0.0008555        186        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.4it/s 0.3s0.7s
#                    all         38        905      0.942      0.809      0.857       0.57
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      11/100       5.3G       1.13     0.3565  0.0009041        218        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.931      0.836      0.848      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      12/100      5.38G      1.085     0.3392  0.0008619        147        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.2s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.946      0.815       0.86      0.591
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      13/100      5.39G      1.102     0.3495  0.0008624        190        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.938      0.742      0.833      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      14/100      5.38G      1.081     0.3415  0.0008501        134        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.4it/s 0.3s0.7s
#                    all         38        905      0.893      0.819      0.842      0.573
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      15/100      5.35G       1.09     0.3441  0.0008759         96        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905       0.92      0.813      0.845      0.558
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      16/100      5.35G      1.093     0.3489  0.0008426        164        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.4s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905       0.88      0.788      0.829      0.577
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      17/100      5.39G      1.083     0.3419  0.0008527        158        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.3it/s 0.3s0.7s
#                    all         38        905      0.936      0.806      0.842      0.559
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      18/100      5.38G       1.08     0.3443  0.0008398        166        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.3s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.4it/s 0.3s0.7s
#                    all         38        905      0.915      0.788      0.839      0.562
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      19/100      5.35G      1.093     0.3368  0.0008511        140        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.7it/s 0.3s0.8s
#                    all         38        905      0.868      0.815      0.848      0.587
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      20/100      5.36G      1.063     0.3319  0.0008238        213        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.7it/s 0.3s0.8s
#                    all         38        905      0.897      0.821      0.834      0.582
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      21/100      5.39G      1.068     0.3363  0.0008237        197        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.6it/s 0.3s0.8s
#                    all         38        905      0.892      0.788      0.834      0.578
#
#       Epoch    GPU_mem   box_loss   cls_loss    l1_loss  Instances       Size
#      22/100      5.38G      1.086     0.3483   0.000827        134        640: 100% ━━━━━━━━━━━━ 77/77 3.6it/s 21.5s0.2ss
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 6.4it/s 0.3s0.8s
#                    all         38        905      0.922      0.791      0.849      0.564
# EarlyStopping: Training stopped early as no improvement observed in last 10 epochs. Best results observed at epoch 12, best model saved as best.pt.
# To update EarlyStopping(patience=10) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 22 epochs completed in 0.140 hours.
# Optimizer stripped from /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2/weights/last.pt, 44.0MB
# Optimizer stripped from /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2/weights/best.pt, 44.0MB
#
# Validating /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2/weights/best.pt...
# Ultralytics 8.4.120 🚀 Python-3.14.4 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5806MiB)
# YOLO26m summary (fused): 132 layers, 20,352,536 parameters, 0 gradients, 68.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 2/2 7.0it/s 0.3s0.7s
#                    all         38        905      0.946      0.815       0.86      0.591
#                   ball         35         35      0.943      0.474      0.514      0.247
#             goalkeeper         27         27      0.938      0.852      0.961      0.714
#                 player         38        754       0.95       0.98      0.993      0.773
#                referee         38         89      0.952      0.955      0.974      0.629
# Speed: 0.2ms preprocess, 5.1ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/mohamed-sameh/Computer_Vision/runs/detect/runs/detect/football_players-2
